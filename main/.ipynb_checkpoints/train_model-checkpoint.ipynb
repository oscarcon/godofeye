# %%
import os
import sys
import cv2
import glob
import joblib
from pathlib import Path
import numpy as np
from time import time
from queue import Queue
from collections import namedtuple

sys.path.append('/home/huy/capstone/godofeye/lib')
sys.path.append('/home/huy/capstone/godofeye/lib/yoloface')

from blueeyes.face_recognition import FaceRecognition, FeatureExtractor, ModelTraining
from blueeyes.face_detection import FaceDetector
from blueeyes.utils import Camera
# Out:
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# Set config.gpu_options.allow_growth to True

# %% [markdown]
# ### Face Crop from Images (Optional)

# %% [markdown]
# from pathlib import Path
#
# IMAGES_DIR = '/home/huy/data/face_recog/train_test_raw/'
# OUTPUT_DIR = '/home/huy/data/face_recog/train_test'
#
# detector = FaceDetector('mtcnn', min_face_size=50)
#
# count = 0
#
# for img_path in glob.glob(IMAGES_DIR + '/**/*.jpg', recursive=True):
#     path = Path(img_path)
#     id = path.parent.name
#     im = cv2.imread(str(path), 1)
#     boxes = detector.detect(im)
#     for left,top,right,bottom in boxes:
#         crop = im[top:bottom,left:right,:]
#         output_dir = OUTPUT_DIR + f'/{id}'
#         output_path = output_dir + f'/{count}.jpg'
#         if not os.path.exists(output_dir):
#             os.makedirs(output_dir)
#         cv2.imwrite(output_path, crop)
#         print('Write to ', output_path)
#         count += 1

# %% [markdown]
# ### Create Train Test Set

# %%
from pathlib import Path

train_set_dict = {}
test_set_dict = {}

# TRAINSET_LOCATION = '/home/huy/Downloads/CBGVDataset_v3.2/Aug3/*/WM/*.jpg'
TESTSET_LOCATION = '/home/huy/smartbuilding/face_recog_models/dataset/CBGVDataset_v2/*/WM/test/*.jpg'
TRAINSET_LOCATION='/home/huy/Downloads/Aug6(train_bri_dark)'


for path in glob.glob(TRAINSET_LOCATION):
    path = Path(path)
    id = path.parent.parent.parent.name
    if id not in train_set_dict.keys():
        train_set_dict[id] = []
    train_set_dict[id].append(str(path)) 
for path in glob.glob(TESTSET_LOCATION):
    path = Path(path)
    id = path.parent.parent.parent.name
    if id not in test_set_dict.keys():
        test_set_dict[id] = []
    test_set_dict[id].append(str(path))

# %%
# auto split train test
from pathlib import Path

RATIO = 1.0

all_set_dict = {}
train_set_dict = {}
test_set_dict = {}

# TRAINSET_LOCATION = '/home/huy/Downloads/Aug5(train+WM)/Aug5/*/train/*.jpg'
# TRAINSET_LOCATION='/home/huy/Downloads/Aug6(train_bri_dark)/*/*.jpg'
TRAINSET_LOCATION = '/home/huy/Downloads/DataFaceID/DATASystem/*/*.jpg'

for path in glob.glob(TRAINSET_LOCATION, recursive=True):
    path = Path(path)
    id = path.parent.name
    if id not in all_set_dict.keys():
        all_set_dict[id] = []
    all_set_dict[id].append(str(path)) 

for label, paths in all_set_dict.items():
    n = int(len(paths)*RATIO)
    train_set_dict[label] = paths[0:n]
    test_set_dict[label] = paths[n:]

# %%
train_set_dict.keys()
# Out:
# dict_keys(['10329_bright', '10229_bright', '10225_bright', '11248', '10354', '11074', '11109_bright', '11500_bright', '10542_bright', '11226_bright', '11243_bright', '11321_bright', '11458_bright', '1641764600_dark', '193019_bright', '10872_dark', '10398_dark', '11072_bright', '11216_bright', '10349_bright', '11499_bright', '11100_dark', '11458_dark', '11102_dark', '11249_dark', '10222_bright', '10635', '10887_bright', '10220_bright', '10888_dark', '9944005072_dark', '11410', '10125_bright', '10473', '10229_dark', '10766_dark', '10307_bright', '10576_bright', '10609_bright', '11272', '11499_dark', '10766_bright', '11280_bright', '11118_dark', '10600_bright', '11409_bright', '11409_dark', '10225_dark', '11489_bright', '10542_dark', '11109_dark', '8493773300_dark', '11280_dark', '10358_dark', '11249_bright', '11245_bright', '11160', '11070_bright', '10609_dark', '11184_bright', '11321_dark', '11281_dark', '11185', '10087_dark', '11201', '10402_bright', '11456_dark', '10358_bright', '10861', '11317', '10600_dark', '11088_bright', '11318_dark', '1149822_dark', '11500_dark', '11267_bright', '11193_bright', '1149822_bright', '10888_bright', '10533_dark', '10276_bright', '10250_bright', '10533_bright', '11214_bright', '11184_dark', '193019_dark', '10359_dark', '11214_dark', '10349_dark', '10283', '10272_dark', '10307_dark', '10423_dark', '11273', '11267_dark', '1641764600_bright', '11251', '11216_dark', '11102_bright', '10329_dark', '11455_dark', '10437_bright', '10423_bright', '10402_dark', '9563444161_dark', '11226_dark', '11243_dark', '10872_bright', '11070_dark', '11489_dark', '10276_dark', '10125_dark', '11318_bright', '10887_dark', '9563444161_bright', '9944005072_bright', '11281_bright', '11468_bright', '11456_bright', '11100_bright', '11193_dark', '11118_bright', '10398_bright', '10250_dark', '10234', '8493773300_bright', '10272_bright', '10171', '10824', '10087_bright', '10576_dark', '10220_dark', '10966', '10437_dark', '11072_dark', '11455_bright', '11468_dark', '11088_dark', '10359_bright', '10222_dark', '11245_dark'])

# %% [markdown]
# ### Create train and test data

# %%
feature_extractor = FeatureExtractor('dlib')
model_trainer = ModelTraining(feature_extractor=feature_extractor)

# %%
model_trainer.create_train_set(train_set_dict, output_model_location='/home/huy/face_recog/encoded_data/aug6_train', process=4)

# %%
model_trainer.create_train_set(test_set_dict, output_model_location='/home/huy/face_recog/encoded_data/test')

# %%
# LOCATION = '/home/huy/Downloads/Aug5(train+WM)/Aug5/*/WM/*.jpg'
LOCATION = '/home/huy/Downloads/CBGVDataset_v3.3(train+test)/*/WM/*.jpg'
data_dict = {}
for path in glob.glob(LOCATION):
    path = Path(path)
    id = path.parent.parent.name
    if id not in data_dict.keys():
        data_dict[id] = []
    data_dict[id].append(str(path))

# %%
data_dict.keys()
# Out:
# dict_keys(['11102', '10222', '11109', '11100', '11468', '11248', '10354', '11074', '1641764600', '10542', '10225', '10635', '11410', '10766', '11321', '10887', '11281', '10888', '10473', '10600', '11409', '10576', '11272', '10872', '9944005072', '11280', '10349', '11458', '11214', '10402', '10272', '10125', '10276', '11499', '11500', '11160', '11243', '10398', '11185', '11201', '10307', '11226', '10861', '11317', '11193', '10533', '10437', '10329', '10358', '10087', '11118', '11249', '10250', '11072', '10283', '11088', '11318', '193019', '11273', '10423', '11251', '11070', '10359', '11216', '11184', '1149822', '9563444161', '11267', '10234', '11456', '11489', '10171', '10824', '10220', '11245', '10966', '11455', '10609', '10229', '8493773300'])

# %%
model_trainer.create_train_set(data_dict, output_model_location='/home/huy/face_recog/encoded_data/aug5_test_wm', process=6)

# %% [markdown]
# ### Train model

# %%
data = joblib.load('/home/huy/face_recog/encoded_data/aug6_train/features.joblib')
features, labels = list(zip(*data))

# %%
data = joblib.load('/home/huy/capstone/godofeye/demo/crop_dataset.joblib')
features, labels = data

# %%
model_trainer.train_knn(features, labels, K=300, weights='uniform', output_model_location='/home/huy/face_recog/models/knn')
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=300, p=2,
#                      weights='uniform')

# %%
model = model_trainer.train_simple_model(features, labels, output_model_location='/home/huy/face_recog/models/simple_distance_test')

# %%
joblib.dump(model, 'centroid.joblib')
# Out:
# ['centroid.joblib']

# %% [markdown]
# ### Train SVM SVC

# %%
import joblib
import numpy as np
from sklearn import svm
from time import time
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from datetime import datetime
C = 100
kernel = 'rbf'
gamma = 10
train_start = time()
clf = svm.SVC(kernel=kernel, C=C, gamma=gamma, probability=True, verbose=True)
# clf = OneVsRestClassifier(svm_clf, n_jobs=-1)
clf.fit(features, labels)
print('Training time: ', time() - train_start)
date = datetime.now().strftime('%d%m%Y_%H%M%S')
joblib.dump(clf, f'/home/huy/face_recog/models/svm/{kernel}_c{C}_g{gamma}_{date}.svm')
# Out:
# [LibSVM]Training time:  1075.9252300262451
# ['/home/huy/face_recog/models/svm/rbf_c100_g10_04072020_174310.svm']

# %%
svm_trained_model_path = f'/home/huy/face_recog/models/svm/{kernel}_c{C}_g{gamma}_{date}.svm'

# %% [markdown]
# ### Train SGDClassifier

# %%
import joblib
import numpy as np
from sklearn.linear_model import SGDClassifier
from time import time
from datetime import datetime

train_start = time()
loss = 'log'
clf = SGDClassifier(loss=loss, max_iter=1000, tol=1e-3, verbose=True)
# clf = OneVsRestClassifier(svm_clf, n_jobs=-1)
clf.fit(features, labels)
print('Training time: ', time() - train_start)
date = datetime.now().strftime('%d%m%Y_%H%M%S')
sgd_trained_model_path = f'/home/huy/face_recog/models/sgd/loss{loss}_{date}.sgd'
joblib.dump(clf, sgd_trained_model_path)

# %%
import joblib
import numpy as np
from time import time
from datetime import datetime
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier

train_start = time()

rbf_feature = RBFSampler(gamma=1, random_state=1)
gaussian_features = rbf_feature.fit_transform(features)
loss = 'log'
clf = SGDClassifier(loss=loss, max_iter=1000, tol=1e-3, verbose=True)
# clf = OneVsRestClassifier(svm_clf, n_jobs=-1)
clf.fit(gaussian_features, labels)
print('Training time: ', time() - train_start)
date = datetime.now().strftime('%d%m%Y_%H%M%S')
sgd_trained_model_path = f'/home/huy/face_recog/models/sgd/RBFSampler_loss{loss}_{date}.sgd'
joblib.dump(clf, sgd_trained_model_path)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# -- Epoch 1
# Norm: 13.22, NNZs: 100, Bias: -6.557617, T: 98700, Avg. loss: 0.014819
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.27, NNZs: 100, Bias: -6.506358, T: 197400, Avg. loss: 0.013875
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 13.25, NNZs: 100, Bias: -6.430628, T: 296100, Avg. loss: 0.013703
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 13.29, NNZs: 100, Bias: -6.332976, T: 394800, Avg. loss: 0.013778
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 13.26, NNZs: 100, Bias: -6.464987, T: 493500, Avg. loss: 0.013692
# Total training time: 0.19 seconds.
# -- Epoch 6
# Norm: 13.29, NNZs: 100, Bias: -6.381207, T: 592200, Avg. loss: 0.013751
# Total training time: 0.24 seconds.
# Convergence after 6 epochs took 0.24 seconds
# -- Epoch 1
# Norm: 12.84, NNZs: 100, Bias: -4.757122, T: 98700, Avg. loss: 0.015769
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.87, NNZs: 100, Bias: -4.739954, T: 197400, Avg. loss: 0.014679
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.82, NNZs: 100, Bias: -4.869506, T: 296100, Avg. loss: 0.014538
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.87, NNZs: 100, Bias: -4.829563, T: 394800, Avg. loss: 0.014689
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 12.87, NNZs: 100, Bias: -4.843223, T: 493500, Avg. loss: 0.014574
# Total training time: 0.19 seconds.
# -- Epoch 6
# Norm: 12.86, NNZs: 100, Bias: -4.880158, T: 592200, Avg. loss: 0.014591
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 12.87, NNZs: 100, Bias: -4.765128, T: 690900, Avg. loss: 0.014580
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 11.73, NNZs: 100, Bias: -5.319912, T: 98700, Avg. loss: 0.024648
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 11.69, NNZs: 100, Bias: -5.316414, T: 197400, Avg. loss: 0.022973
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 11.72, NNZs: 100, Bias: -5.368223, T: 296100, Avg. loss: 0.023043
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 11.69, NNZs: 100, Bias: -5.519101, T: 394800, Avg. loss: 0.022884
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 11.68, NNZs: 100, Bias: -5.532691, T: 493500, Avg. loss: 0.022919
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 11.70, NNZs: 100, Bias: -5.408165, T: 592200, Avg. loss: 0.022936
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 11.70, NNZs: 100, Bias: -5.522605, T: 690900, Avg. loss: 0.022936
# Total training time: 0.27 seconds.
# Convergence after 7 epochs took 0.27 seconds
# Norm: 12.52, NNZs: 100, Bias: -5.806008, T: 690900, Avg. loss: 0.013750
# Total training time: 0.39 seconds.
# Convergence after 7 epochs took 0.39 seconds
# -- Epoch 1
# Norm: 12.37, NNZs: 100, Bias: -6.212648, T: 98700, Avg. loss: 0.014212
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 12.27, NNZs: 100, Bias: -6.568773, T: 197400, Avg. loss: 0.013120
# Total training time: 0.14 seconds.
# -- Epoch 3
# Norm: 12.31, NNZs: 100, Bias: -6.436057, T: 296100, Avg. loss: 0.013092
# Total training time: 0.20 seconds.
# -- Epoch 4
# Norm: 12.30, NNZs: 100, Bias: -6.457875, T: 394800, Avg. loss: 0.013061
# Total training time: 0.26 seconds.
# -- Epoch 5
# Norm: 12.28, NNZs: 100, Bias: -6.481021, T: 493500, Avg. loss: 0.013024
# Total training time: 0.35 seconds.
# -- Epoch 6
# Norm: 12.31, NNZs: 100, Bias: -6.425978, T: 592200, Avg. loss: 0.013086
# Total training time: 0.41 seconds.
# -- Epoch 7
# Norm: 12.32, NNZs: 100, Bias: -6.397169, T: 690900, Avg. loss: 0.013062
# Total training time: 0.45 seconds.
# Convergence after 7 epochs took 0.45 seconds
# -- Epoch 1
# Norm: 12.00, NNZs: 100, Bias: -7.479669, T: 98700, Avg. loss: 0.026329
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.01, NNZs: 100, Bias: -7.691440, T: 197400, Avg. loss: 0.024526
# Total training time: 0.10 seconds.
# -- Epoch 3
# Norm: 11.95, NNZs: 100, Bias: -7.916624, T: 296100, Avg. loss: 0.024317
# Total training time: 0.19 seconds.
# -- Epoch 4
# Norm: 11.98, NNZs: 100, Bias: -7.870989, T: 394800, Avg. loss: 0.024344
# Total training time: 0.27 seconds.
# -- Epoch 5
# Norm: 11.97, NNZs: 100, Bias: -7.913721, T: 493500, Avg. loss: 0.024254
# Total training time: 0.32 seconds.
# -- Epoch 6
# Norm: 11.97, NNZs: 100, Bias: -7.891252, T: 592200, Avg. loss: 0.024174
# Total training time: 0.37 seconds.
# -- Epoch 7
# Norm: 12.00, NNZs: 100, Bias: -7.823552, T: 690900, Avg. loss: 0.024238
# Total training time: 0.41 seconds.
# Convergence after 7 epochs took 0.41 seconds
# -- Epoch 1
# Norm: 11.98, NNZs: 100, Bias: -6.518454, T: 98700, Avg. loss: 0.009231
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 11.94, NNZs: 100, Bias: -6.637481, T: 197400, Avg. loss: 0.008560
# Total training time: 0.14 seconds.
# -- Epoch 3
# Norm: 11.96, NNZs: 100, Bias: -6.529260, T: 296100, Avg. loss: 0.008513
# Total training time: 0.21 seconds.
# -- Epoch 4
# Norm: 11.95, NNZs: 100, Bias: -6.629018, T: 394800, Avg. loss: 0.008558
# Total training time: 0.27 seconds.
# -- Epoch 5
# Norm: 11.94, NNZs: 100, Bias: -6.608327, T: 493500, Avg. loss: 0.008507
# Total training time: 0.30 seconds.
# -- Epoch 6
# Norm: 11.92, NNZs: 100, Bias: -6.664670, T: 592200, Avg. loss: 0.008514
# Total training time: 0.37 seconds.
# Convergence after 6 epochs took 0.37 seconds
# -- Epoch 1
# Norm: 11.66, NNZs: 100, Bias: -5.688619, T: 98700, Avg. loss: 0.012362
# Total training time: 0.11 seconds.
# -- Epoch 2
# Norm: 11.57, NNZs: 100, Bias: -5.825760, T: 197400, Avg. loss: 0.011401
# Total training time: 0.17 seconds.
# -- Epoch 3
# Norm: 11.59, NNZs: 100, Bias: -5.810631, T: 296100, Avg. loss: 0.011458
# Total training time: 0.21 seconds.
# -- Epoch 4
# Norm: 11.67, NNZs: 100, Bias: -5.639501, T: 394800, Avg. loss: 0.011459
# Total training time: 0.27 seconds.
# -- Epoch 5
# Norm: 11.66, NNZs: 100, Bias: -5.669530, T: 493500, Avg. loss: 0.011383
# Total training time: 0.37 seconds.
# -- Epoch 6
# Norm: 11.66, NNZs: 100, Bias: -5.695656, T: 592200, Avg. loss: 0.011414
# Total training time: 0.44 seconds.
# Convergence after 6 epochs took 0.44 seconds
# -- Epoch 1
# Norm: 12.47, NNZs: 100, Bias: -5.439821, T: 98700, Avg. loss: 0.009179
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 12.47, NNZs: 100, Bias: -5.357523, T: 197400, Avg. loss: 0.008571
# Total training time: 0.10 seconds.
# -- Epoch 3
# Norm: 12.46, NNZs: 100, Bias: -5.445359, T: 296100, Avg. loss: 0.008585
# Total training time: 0.14 seconds.
# -- Epoch 4
# Norm: 12.48, NNZs: 100, Bias: -5.402360, T: 394800, Avg. loss: 0.008589
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 12.47, NNZs: 100, Bias: -5.430943, T: 493500, Avg. loss: 0.008555
# Total training time: 0.24 seconds.
# -- Epoch 6
# Norm: 12.44, NNZs: 100, Bias: -5.491501, T: 592200, Avg. loss: 0.008516
# Total training time: 0.33 seconds.
# Convergence after 6 epochs took 0.33 seconds
# -- Epoch 1
# Norm: 12.41, NNZs: 100, Bias: -5.577103, T: 98700, Avg. loss: 0.008346
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 12.40, NNZs: 100, Bias: -5.438691, T: 197400, Avg. loss: 0.007719
# Total training time: 0.12 seconds.
# -- Epoch 3
# Norm: 12.34, NNZs: 100, Bias: -5.560985, T: 296100, Avg. loss: 0.007669
# Total training time: 0.18 seconds.
# -- Epoch 4
# Norm: 12.32, NNZs: 100, Bias: -5.635698, T: 394800, Avg. loss: 0.007674
# Total training time: 0.22 seconds.
# -- Epoch 5
# Norm: 12.33, NNZs: 100, Bias: -5.595656, T: 493500, Avg. loss: 0.007709
# Total training time: 0.26 seconds.
# -- Epoch 6
# Norm: 12.34, NNZs: 100, Bias: -5.588493, T: 592200, Avg. loss: 0.007719
# Total training time: 0.30 seconds.
# Convergence after 6 epochs took 0.30 seconds
# -- Epoch 1
# Norm: 13.35, NNZs: 100, Bias: -5.981892, T: 98700, Avg. loss: 0.015817
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.56, NNZs: 100, Bias: -8.608853, T: 197400, Avg. loss: 0.014936
# Total training time: 0.14 seconds.
# -- Epoch 3
# Norm: 13.56, NNZs: 100, Bias: -8.635796, T: 296100, Avg. loss: 0.014875
# Total training time: 0.20 seconds.
# -- Epoch 4
# Norm: 13.57, NNZs: 100, Bias: -8.567122, T: 394800, Avg. loss: 0.014781
# Total training time: 0.26 seconds.
# -- Epoch 5
# Norm: 13.56, NNZs: 100, Bias: -8.595877, T: 493500, Avg. loss: 0.014810
# Total training time: 0.30 seconds.
# -- Epoch 6
# Norm: 13.57, NNZs: 100, Bias: -8.578939, T: 592200, Avg. loss: 0.014796
# Total training time: 0.34 seconds.
# -- Epoch 7
# Norm: 13.59, NNZs: 100, Bias: -8.506107, T: 690900, Avg. loss: 0.014794
# Total training time: 0.38 seconds.
# Convergence after 7 epochs took 0.38 seconds
# -- Epoch 1
# Norm: 13.43, NNZs: 100, Bias: -8.301424, T: 98700, Avg. loss: 0.014553
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.27, NNZs: 100, Bias: -8.649874, T: 197400, Avg. loss: 0.013385
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.27, NNZs: 100, Bias: -8.696544, T: 296100, Avg. loss: 0.013397
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 13.31, NNZs: 100, Bias: -8.571359, T: 394800, Avg. loss: 0.013293
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 13.28, NNZs: 100, Bias: -8.665189, T: 493500, Avg. loss: 0.013319
# Total training time: 0.19 seconds.
# -- Epoch 6
# Norm: 13.26, NNZs: 100, Bias: -8.682436, T: 592200, Avg. loss: 0.013271
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 13.26, NNZs: 100, Bias: -8.691030, T: 690900, Avg. loss: 0.013284
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 13.12, NNZs: 100, Bias: -5.411399, T: 98700, Avg. loss: 0.014491
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.08, NNZs: 100, Bias: -5.514520, T: 197400, Avg. loss: 0.013384
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 13.12, NNZs: 100, Bias: -5.456314, T: 296100, Avg. loss: 0.013407
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 13.09, NNZs: 100, Bias: -5.597687, T: 394800, Avg. loss: 0.013342
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 13.10, NNZs: 100, Bias: -5.597035, T: 493500, Avg. loss: 0.013359
# Total training time: 0.24 seconds.
# -- Epoch 6
# Norm: 13.10, NNZs: 100, Bias: -5.598674, T: 592200, Avg. loss: 0.013318
# Total training time: 0.35 seconds.
# -- Epoch 7
# Norm: 13.10, NNZs: 100, Bias: -5.566204, T: 690900, Avg. loss: 0.013357
# Total training time: 0.41 seconds.
# Convergence after 7 epochs took 0.41 seconds
# Norm: 12.85, NNZs: 100, Bias: -7.043001, T: 690900, Avg. loss: 0.016729
# Total training time: 0.40 seconds.
# Convergence after 7 epochs took 0.40 seconds
# -- Epoch 1
# Norm: 13.16, NNZs: 100, Bias: -5.844150, T: 98700, Avg. loss: 0.010430
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.08, NNZs: 100, Bias: -5.972509, T: 197400, Avg. loss: 0.009525
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.10, NNZs: 100, Bias: -5.914771, T: 296100, Avg. loss: 0.009563
# Total training time: 0.14 seconds.
# -- Epoch 4
# Norm: 13.13, NNZs: 100, Bias: -5.868326, T: 394800, Avg. loss: 0.009589
# Total training time: 0.22 seconds.
# -- Epoch 5
# Norm: 13.16, NNZs: 100, Bias: -5.764183, T: 493500, Avg. loss: 0.009575
# Total training time: 0.28 seconds.
# -- Epoch 6
# Norm: 13.15, NNZs: 100, Bias: -5.816912, T: 592200, Avg. loss: 0.009549
# Total training time: 0.34 seconds.
# Convergence after 6 epochs took 0.34 seconds
# -- Epoch 1
# Norm: 12.53, NNZs: 100, Bias: -6.246796, T: 98700, Avg. loss: 0.020542
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.41, NNZs: 100, Bias: -6.182076, T: 197400, Avg. loss: 0.018966
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 12.34, NNZs: 100, Bias: -6.309567, T: 296100, Avg. loss: 0.018823
# Total training time: 0.18 seconds.
# -- Epoch 4
# Norm: 12.38, NNZs: 100, Bias: -6.064435, T: 394800, Avg. loss: 0.018908
# Total training time: 0.26 seconds.
# -- Epoch 5
# Norm: 12.34, NNZs: 100, Bias: -6.202306, T: 493500, Avg. loss: 0.018841
# Total training time: 0.33 seconds.
# -- Epoch 6
# Norm: 12.33, NNZs: 100, Bias: -6.162411, T: 592200, Avg. loss: 0.018800
# Total training time: 0.36 seconds.
# -- Epoch 7
# Norm: 12.32, NNZs: 100, Bias: -6.204678, T: 690900, Avg. loss: 0.018833
# Total training time: 0.40 seconds.
# Convergence after 7 epochs took 0.40 seconds
# -- Epoch 1
# Norm: 13.15, NNZs: 100, Bias: -7.233972, T: 98700, Avg. loss: 0.016733
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 12.92, NNZs: 100, Bias: -7.452619, T: 197400, Avg. loss: 0.015164
# Total training time: 0.15 seconds.
# -- Epoch 3
# Norm: 12.98, NNZs: 100, Bias: -7.329625, T: 296100, Avg. loss: 0.015320
# Total training time: 0.21 seconds.
# -- Epoch 4
# Norm: 13.04, NNZs: 100, Bias: -7.232532, T: 394800, Avg. loss: 0.015371
# Total training time: 0.25 seconds.
# -- Epoch 5
# Norm: 13.01, NNZs: 100, Bias: -7.336960, T: 493500, Avg. loss: 0.015277
# Total training time: 0.29 seconds.
# -- Epoch 6
# Norm: 13.02, NNZs: 100, Bias: -7.314273, T: 592200, Avg. loss: 0.015264
# Total training time: 0.34 seconds.
# -- Epoch 7
# Norm: 13.03, NNZs: 100, Bias: -7.276658, T: 690900, Avg. loss: 0.015263
# Total training time: 0.37 seconds.
# Convergence after 7 epochs took 0.37 seconds
# -- Epoch 1
# Norm: 13.23, NNZs: 100, Bias: -5.098195, T: 98700, Avg. loss: 0.016589
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.11, NNZs: 100, Bias: -5.220756, T: 197400, Avg. loss: 0.015195
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.13, NNZs: 100, Bias: -5.262606, T: 296100, Avg. loss: 0.015360
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 13.14, NNZs: 100, Bias: -5.130983, T: 394800, Avg. loss: 0.015248
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.14, NNZs: 100, Bias: -5.124535, T: 493500, Avg. loss: 0.015223
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.13, NNZs: 100, Bias: -5.194411, T: 592200, Avg. loss: 0.015254
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 13.13, NNZs: 100, Bias: -5.190872, T: 690900, Avg. loss: 0.015210
# Total training time: 0.29 seconds.
# Convergence after 7 epochs took 0.29 seconds
# -- Epoch 1
# Norm: 12.92, NNZs: 100, Bias: -5.624230, T: 98700, Avg. loss: 0.018639
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.99, NNZs: 100, Bias: -5.452767, T: 197400, Avg. loss: 0.017442
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.95, NNZs: 100, Bias: -5.613071, T: 296100, Avg. loss: 0.017229
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.94, NNZs: 100, Bias: -5.416198, T: 394800, Avg. loss: 0.017110
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.93, NNZs: 100, Bias: -5.429909, T: 493500, Avg. loss: 0.017205
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.92, NNZs: 100, Bias: -5.551672, T: 592200, Avg. loss: 0.017188
# Total training time: 0.26 seconds.
# -- Epoch 7
# Norm: 12.90, NNZs: 100, Bias: -5.622512, T: 690900, Avg. loss: 0.017133
# Total training time: 0.35 seconds.
# Convergence after 7 epochs took 0.35 seconds
# -- Epoch 1
# Norm: 12.71, NNZs: 100, Bias: -4.071255, T: 98700, Avg. loss: 0.017273
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 12.56, NNZs: 100, Bias: -4.203029, T: 197400, Avg. loss: 0.015645
# Total training time: 0.14 seconds.
# -- Epoch 3
# Norm: 12.56, NNZs: 100, Bias: -4.133002, T: 296100, Avg. loss: 0.015722
# Total training time: 0.18 seconds.
# -- Epoch 4
# Norm: 12.57, NNZs: 100, Bias: -4.190320, T: 394800, Avg. loss: 0.015720
# Total training time: 0.22 seconds.
# -- Epoch 5
# Norm: 12.56, NNZs: 100, Bias: -4.204116, T: 493500, Avg. loss: 0.015681
# Total training time: 0.27 seconds.
# -- Epoch 6
# Norm: 13.58, NNZs: 100, Bias: -6.256865, T: 493500, Avg. loss: 0.015327
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.56, NNZs: 100, Bias: -6.373033, T: 592200, Avg. loss: 0.015227
# Total training time: 0.23 seconds.
# -- Epoch 7
# Norm: 13.56, NNZs: 100, Bias: -6.344812, T: 690900, Avg. loss: 0.015212
# Total training time: 0.27 seconds.
# Convergence after 7 epochs took 0.27 seconds
# -- Epoch 1
# Norm: 13.04, NNZs: 100, Bias: -5.832740, T: 98700, Avg. loss: 0.014383
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.02, NNZs: 100, Bias: -5.610090, T: 197400, Avg. loss: 0.013574
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.04, NNZs: 100, Bias: -5.616486, T: 296100, Avg. loss: 0.013589
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.03, NNZs: 100, Bias: -5.652541, T: 394800, Avg. loss: 0.013533
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.03, NNZs: 100, Bias: -5.685714, T: 493500, Avg. loss: 0.013563
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.05, NNZs: 100, Bias: -5.554204, T: 592200, Avg. loss: 0.013560
# Total training time: 0.25 seconds.
# Convergence after 6 epochs took 0.25 seconds
# -- Epoch 1
# Norm: 12.36, NNZs: 100, Bias: -5.007435, T: 98700, Avg. loss: 0.018438
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 12.43, NNZs: 100, Bias: -5.060522, T: 197400, Avg. loss: 0.017590
# Total training time: 0.14 seconds.
# -- Epoch 3
# Norm: 12.46, NNZs: 100, Bias: -5.014174, T: 296100, Avg. loss: 0.017532
# Total training time: 0.21 seconds.
# -- Epoch 4
# Norm: 12.45, NNZs: 100, Bias: -5.117383, T: 394800, Avg. loss: 0.017415
# Total training time: 0.27 seconds.
# -- Epoch 5
# Norm: 12.46, NNZs: 100, Bias: -5.072581, T: 493500, Avg. loss: 0.017434
# Total training time: 0.31 seconds.
# -- Epoch 6
# Norm: 12.46, NNZs: 100, Bias: -5.069083, T: 592200, Avg. loss: 0.017433
# Total training time: 0.35 seconds.
# Convergence after 6 epochs took 0.35 seconds
# -- Epoch 1
# Norm: 11.87, NNZs: 100, Bias: -4.944022, T: 98700, Avg. loss: 0.008178
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 11.70, NNZs: 100, Bias: -5.017760, T: 197400, Avg. loss: 0.007333
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 11.68, NNZs: 100, Bias: -5.071388, T: 296100, Avg. loss: 0.007377
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 11.70, NNZs: 100, Bias: -5.059993, T: 394800, Avg. loss: 0.007425
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 11.69, NNZs: 100, Bias: -5.084199, T: 493500, Avg. loss: 0.007386
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 11.70, NNZs: 100, Bias: -5.086103, T: 592200, Avg. loss: 0.007414
# Total training time: 0.23 seconds.
# Convergence after 6 epochs took 0.23 seconds
# -- Epoch 1
# Norm: 12.48, NNZs: 100, Bias: -4.568845, T: 98700, Avg. loss: 0.011423
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.38, NNZs: 100, Bias: -4.692904, T: 197400, Avg. loss: 0.010568
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.37, NNZs: 100, Bias: -4.644510, T: 296100, Avg. loss: 0.010534
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 12.34, NNZs: 100, Bias: -4.758063, T: 394800, Avg. loss: 0.010498
# Total training time: 0.21 seconds.
# -- Epoch 5
# Norm: 12.34, NNZs: 100, Bias: -4.751571, T: 493500, Avg. loss: 0.010527
# Total training time: 0.29 seconds.
# -- Epoch 6
# Norm: 12.36, NNZs: 100, Bias: -4.650827, T: 592200, Avg. loss: 0.010536
# Total training time: 0.36 seconds.
# Convergence after 6 epochs took 0.36 seconds
# -- Epoch 1
# Norm: 12.87, NNZs: 100, Bias: -5.660169, T: 98700, Avg. loss: 0.019224
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.88, NNZs: 100, Bias: -5.505600, T: 197400, Avg. loss: 0.017881
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.87, NNZs: 100, Bias: -5.655125, T: 296100, Avg. loss: 0.017871
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.87, NNZs: 100, Bias: -5.617038, T: 394800, Avg. loss: 0.017783
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.87, NNZs: 100, Bias: -5.595928, T: 493500, Avg. loss: 0.017788
# Total training time: 0.23 seconds.
# -- Epoch 6
# Norm: 12.88, NNZs: 100, Bias: -5.506616, T: 592200, Avg. loss: 0.017768
# Total training time: 0.30 seconds.
# -- Epoch 7
# Norm: 12.86, NNZs: 100, Bias: -5.563944, T: 690900, Avg. loss: 0.017732
# Total training time: 0.36 seconds.
# Convergence after 7 epochs took 0.36 seconds
# -- Epoch 1
# Norm: 12.96, NNZs: 100, Bias: -5.409639, T: 98700, Avg. loss: 0.010160
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 12.92, NNZs: 100, Bias: -5.366819, T: 197400, Avg. loss: 0.009343
# Total training time: 0.11 seconds.
# -- Epoch 3
# Norm: 12.91, NNZs: 100, Bias: -5.430842, T: 296100, Avg. loss: 0.009361
# Total training time: 0.14 seconds.
# -- Epoch 4
# Norm: 12.93, NNZs: 100, Bias: -5.380243, T: 394800, Avg. loss: 0.009363
# Total training time: 0.20 seconds.
# -- Epoch 5
# Norm: 12.89, NNZs: 100, Bias: -5.492493, T: 493500, Avg. loss: 0.009290
# Total training time: 0.30 seconds.
# -- Epoch 6
# Norm: 12.89, NNZs: 100, Bias: -5.497014, T: 592200, Avg. loss: 0.009331
# Total training time: 0.37 seconds.
# Convergence after 6 epochs took 0.37 seconds
# -- Epoch 1
# Norm: 12.56, NNZs: 100, Bias: -5.205791, T: 98700, Avg. loss: 0.014347
# Total training time: 0.05 seconds.
# -- Epoch 2
# Norm: 12.56, NNZs: 100, Bias: -5.121347, T: 197400, Avg. loss: 0.013185
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 12.57, NNZs: 100, Bias: -5.087065, T: 296100, Avg. loss: 0.013227
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 12.54, NNZs: 100, Bias: -5.246563, T: 394800, Avg. loss: 0.013167
# Total training time: 0.22 seconds.
# -- Epoch 5
# Norm: 12.57, NNZs: 100, Bias: -5.168369, T: 493500, Avg. loss: 0.013214
# Total training time: 0.30 seconds.
# -- Epoch 6
# Norm: 12.55, NNZs: 100, Bias: -5.218521, T: 592200, Avg. loss: 0.013120
# Total training time: 0.38 seconds.
# -- Epoch 7
# Norm: 12.57, NNZs: 100, Bias: -5.112143, T: 690900, Avg. loss: 0.013203
# Total training time: 0.43 seconds.
# Convergence after 7 epochs took 0.43 seconds
# -- Epoch 1
# Norm: 13.21, NNZs: 100, Bias: -7.517445, T: 98700, Avg. loss: 0.015953
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.19, NNZs: 100, Bias: -7.753291, T: 197400, Avg. loss: 0.014794
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.21, NNZs: 100, Bias: -7.564311, T: 296100, Avg. loss: 0.014576
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 13.16, NNZs: 100, Bias: -7.742291, T: 394800, Avg. loss: 0.014634
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 13.19, NNZs: 100, Bias: -7.681558, T: 493500, Avg. loss: 0.014618
# Total training time: 0.22 seconds.
# -- Epoch 6
# Norm: 13.21, NNZs: 100, Bias: -7.607265, T: 592200, Avg. loss: 0.014624
# Total training time: 0.29 seconds.
# -- Epoch 7
# Norm: 13.18, NNZs: 100, Bias: -7.718561, T: 690900, Avg. loss: 0.014576
# Total training time: 0.35 seconds.
# Convergence after 7 epochs took 0.35 seconds
# -- Epoch 1
# Norm: 12.22, NNZs: 100, Bias: -8.551502, T: 98700, Avg. loss: 0.022613
# Total training time: 0.08 seconds.
# -- Epoch 2
# Norm: 12.22, NNZs: 100, Bias: -8.543001, T: 197400, Avg. loss: 0.020955
# Total training time: 0.12 seconds.
# -- Epoch 3
# Norm: 12.25, NNZs: 100, Bias: -8.480039, T: 296100, Avg. loss: 0.020829
# Total training time: 0.16 seconds.
# -- Epoch 4
# Norm: 12.22, NNZs: 100, Bias: -8.547375, T: 394800, Avg. loss: 0.020772
# Total training time: 0.20 seconds.
# -- Epoch 5
# Norm: 12.23, NNZs: 100, Bias: -8.536806, T: 493500, Avg. loss: 0.020722
# Total training time: 0.24 seconds.
# -- Epoch 6
# Norm: 12.25, NNZs: 100, Bias: -8.505614, T: 592200, Avg. loss: 0.020762
# Total training time: 0.27 seconds.
# -- Epoch 7
# Norm: 12.23, NNZs: 100, Bias: -8.540161, T: 690900, Avg. loss: 0.020689
# Total training time: 0.32 seconds.
# Convergence after 7 epochs took 0.32 seconds
# -- Epoch 1
# Norm: 13.14, NNZs: 100, Bias: -5.884132, T: 98700, Avg. loss: 0.013900
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.18, NNZs: 100, Bias: -6.055701, T: 197400, Avg. loss: 0.012793
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.20, NNZs: 100, Bias: -6.069894, T: 296100, Avg. loss: 0.012810
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.21, NNZs: 100, Bias: -6.032580, T: 394800, Avg. loss: 0.012782
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.22, NNZs: 100, Bias: -6.003251, T: 493500, Avg. loss: 0.012739
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.24, NNZs: 100, Bias: -5.936404, T: 592200, Avg. loss: 0.012788
# Total training time: 0.25 seconds.
# -- Epoch 7
# Norm: 13.22, NNZs: 100, Bias: -6.050584, T: 690900, Avg. loss: 0.012741
# Total training time: 0.29 seconds.
# Convergence after 7 epochs took 0.29 seconds
# -- Epoch 1
# Norm: 13.49, NNZs: 100, Bias: -7.142035, T: 98700, Avg. loss: 0.014457
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.58, NNZs: 100, Bias: -7.126024, T: 197400, Avg. loss: 0.013560
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.59, NNZs: 100, Bias: -7.133926, T: 296100, Avg. loss: 0.013495
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.57, NNZs: 100, Bias: -7.163457, T: 394800, Avg. loss: 0.013420
# Total training time: 0.20 seconds.
# -- Epoch 5
# Norm: 13.57, NNZs: 100, Bias: -7.172328, T: 493500, Avg. loss: 0.013470
# Total training time: 0.28 seconds.
# -- Epoch 6
# Norm: 13.58, NNZs: 100, Bias: -7.159758, T: 592200, Avg. loss: 0.013436
# Total training time: 0.36 seconds.
# Convergence after 6 epochs took 0.36 seconds
# -- Epoch 1
# Norm: 13.32, NNZs: 100, Bias: -7.774157, T: 98700, Avg. loss: 0.019419
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 13.19, NNZs: 100, Bias: -8.025800, T: 197400, Avg. loss: 0.017804
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 13.13, NNZs: 100, Bias: -8.135640, T: 296100, Avg. loss: 0.017671
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 13.15, NNZs: 100, Bias: -8.023623, T: 394800, Avg. loss: 0.017701
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 13.17, NNZs: 100, Bias: -7.964385, T: 493500, Avg. loss: 0.017674
# Total training time: 0.21 seconds.
# -- Epoch 6
# Norm: 13.18, NNZs: 100, Bias: -7.950035, T: 592200, Avg. loss: 0.017725
# Total training time: 0.31 seconds.
# -- Epoch 7
# Norm: 13.17, NNZs: 100, Bias: -7.983592, T: 690900, Avg. loss: 0.017694
# Total training time: 0.38 seconds.
# Convergence after 7 epochs took 0.38 seconds
# -- Epoch 1
# Norm: 13.63, NNZs: 100, Bias: -7.082741, T: 98700, Avg. loss: 0.015863
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 13.81, NNZs: 100, Bias: -6.872875, T: 197400, Avg. loss: 0.014979
# Total training time: 0.12 seconds.
# -- Epoch 3
# Norm: 13.78, NNZs: 100, Bias: -6.980402, T: 296100, Avg. loss: 0.014755
# Total training time: 0.16 seconds.
# -- Epoch 4
# Norm: 13.80, NNZs: 100, Bias: -6.928955, T: 394800, Avg. loss: 0.014818
# Total training time: 0.20 seconds.
# -- Epoch 5
# Norm: 13.79, NNZs: 100, Bias: -6.970452, T: 493500, Avg. loss: 0.014710
# Total training time: 0.24 seconds.
# -- Epoch 6
# Norm: 13.80, NNZs: 100, Bias: -6.908712, T: 592200, Avg. loss: 0.014749
# Total training time: 0.28 seconds.
# Convergence after 6 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 13.50, NNZs: 100, Bias: -5.092969, T: 98700, Avg. loss: 0.012207
# Total training time: 0.05 seconds.
# -- Epoch 2
# Norm: 13.60, NNZs: 100, Bias: -5.094881, T: 197400, Avg. loss: 0.011682
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 13.62, NNZs: 100, Bias: -5.091593, T: 296100, Avg. loss: 0.011604
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 13.59, NNZs: 100, Bias: -5.125459, T: 394800, Avg. loss: 0.011489
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 13.60, NNZs: 100, Bias: -5.001844, T: 493500, Avg. loss: 0.011540
# Total training time: 0.25 seconds.
# -- Epoch 6
# Norm: 13.60, NNZs: 100, Bias: -5.107011, T: 592200, Avg. loss: 0.011562
# Total training time: 0.33 seconds.
# Convergence after 6 epochs took 0.33 seconds
# -- Epoch 1
# Norm: 12.84, NNZs: 100, Bias: -5.896563, T: 98700, Avg. loss: 0.019999
# Total training time: 0.07 seconds.
# -- Epoch 2
# Norm: 12.86, NNZs: 100, Bias: -5.909905, T: 197400, Avg. loss: 0.018745
# Total training time: 0.13 seconds.
# -- Epoch 3
# Norm: 12.83, NNZs: 100, Bias: -6.234716, T: 296100, Avg. loss: 0.018719
# Total training time: 0.19 seconds.
# -- Epoch 4
# Norm: 12.88, NNZs: 100, Bias: -5.988333, T: 394800, Avg. loss: 0.018701
# Total training time: 0.23 seconds.
# -- Epoch 5
# Norm: 12.85, NNZs: 100, Bias: -6.102420, T: 493500, Avg. loss: 0.018665
# Total training time: 0.26 seconds.
# -- Epoch 6
# Norm: 12.85, NNZs: 100, Bias: -6.102291, T: 592200, Avg. loss: 0.018633
# Total training time: 0.30 seconds.
# -- Epoch 7
# Norm: 12.85, NNZs: 100, Bias: -6.076361, T: 690900, Avg. loss: 0.018650
# Total training time: 0.34 seconds.
# Convergence after 7 epochs took 0.34 seconds
# -- Epoch 3
# Norm: 12.26, NNZs: 100, Bias: -3.708564, T: 296100, Avg. loss: 0.008447
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.26, NNZs: 100, Bias: -3.647840, T: 394800, Avg. loss: 0.008490
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.24, NNZs: 100, Bias: -3.730926, T: 493500, Avg. loss: 0.008424
# Total training time: 0.23 seconds.
# -- Epoch 6
# Norm: 12.24, NNZs: 100, Bias: -3.712945, T: 592200, Avg. loss: 0.008472
# Total training time: 0.31 seconds.
# Convergence after 6 epochs took 0.31 seconds
# -- Epoch 1
# Norm: 13.55, NNZs: 100, Bias: -4.857426, T: 98700, Avg. loss: 0.013147
# Total training time: 0.08 seconds.
# -- Epoch 2
# Norm: 13.31, NNZs: 100, Bias: -5.051993, T: 197400, Avg. loss: 0.011823
# Total training time: 0.13 seconds.
# -- Epoch 3
# Norm: 13.25, NNZs: 100, Bias: -5.124475, T: 296100, Avg. loss: 0.011838
# Total training time: 0.17 seconds.
# -- Epoch 4
# Norm: 13.24, NNZs: 100, Bias: -5.010375, T: 394800, Avg. loss: 0.011833
# Total training time: 0.21 seconds.
# -- Epoch 5
# Norm: 13.24, NNZs: 100, Bias: -5.032212, T: 493500, Avg. loss: 0.011863
# Total training time: 0.25 seconds.
# -- Epoch 6
# Norm: 13.22, NNZs: 100, Bias: -5.074601, T: 592200, Avg. loss: 0.011831
# Total training time: 0.29 seconds.
# -- Epoch 7
# Norm: 13.22, NNZs: 100, Bias: -5.058814, T: 690900, Avg. loss: 0.011825
# Total training time: 0.33 seconds.
# Convergence after 7 epochs took 0.33 seconds
# -- Epoch 1
# Norm: 13.05, NNZs: 100, Bias: -5.323526, T: 98700, Avg. loss: 0.018869
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.05, NNZs: 100, Bias: -5.246261, T: 197400, Avg. loss: 0.017409
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.02, NNZs: 100, Bias: -5.434229, T: 296100, Avg. loss: 0.017329
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.00, NNZs: 100, Bias: -5.509168, T: 394800, Avg. loss: 0.017271
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 13.01, NNZs: 100, Bias: -5.407465, T: 493500, Avg. loss: 0.017290
# Total training time: 0.24 seconds.
# -- Epoch 6
# Norm: 13.01, NNZs: 100, Bias: -5.411577, T: 592200, Avg. loss: 0.017274
# Total training time: 0.31 seconds.
# -- Epoch 7
# Norm: 13.01, NNZs: 100, Bias: -5.366995, T: 690900, Avg. loss: 0.017281
# Total training time: 0.39 seconds.
# Convergence after 7 epochs took 0.39 seconds
# -- Epoch 1
# Norm: 13.20, NNZs: 100, Bias: -5.460840, T: 98700, Avg. loss: 0.013739
# Total training time: 0.06 seconds.
# -- Epoch 2
# Norm: 13.21, NNZs: 100, Bias: -5.628897, T: 197400, Avg. loss: 0.012904
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 13.25, NNZs: 100, Bias: -5.584237, T: 296100, Avg. loss: 0.012934
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 13.27, NNZs: 100, Bias: -5.575960, T: 394800, Avg. loss: 0.012918
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 13.25, NNZs: 100, Bias: -5.623134, T: 493500, Avg. loss: 0.012829
# Total training time: 0.21 seconds.
# -- Epoch 6
# Norm: 13.24, NNZs: 100, Bias: -5.672135, T: 592200, Avg. loss: 0.012826
# Total training time: 0.25 seconds.
# Convergence after 6 epochs took 0.25 seconds
# -- Epoch 1
# ...
# Norm: 12.78, NNZs: 100, Bias: -7.658153, T: 98700, Avg. loss: 0.018929
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.89, NNZs: 100, Bias: -7.652866, T: 197400, Avg. loss: 0.017735
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.89, NNZs: 100, Bias: -7.695718, T: 296100, Avg. loss: 0.017637
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 12.86, NNZs: 100, Bias: -7.784566, T: 394800, Avg. loss: 0.017558
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.86, NNZs: 100, Bias: -7.777254, T: 493500, Avg. loss: 0.017505
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.85, NNZs: 100, Bias: -7.811509, T: 592200, Avg. loss: 0.017504
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 12.84, NNZs: 100, Bias: -7.817423, T: 690900, Avg. loss: 0.017512
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 13.23, NNZs: 100, Bias: -4.862865, T: 98700, Avg. loss: 0.015823
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.52, NNZs: 100, Bias: -4.825242, T: 197400, Avg. loss: 0.015260
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.50, NNZs: 100, Bias: -4.917050, T: 296100, Avg. loss: 0.014886
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.48, NNZs: 100, Bias: -5.071810, T: 394800, Avg. loss: 0.014872
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.49, NNZs: 100, Bias: -5.004147, T: 493500, Avg. loss: 0.014885
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.49, NNZs: 100, Bias: -4.953144, T: 592200, Avg. loss: 0.014831
# Total training time: 0.24 seconds.
# Convergence after 6 epochs took 0.24 seconds
# -- Epoch 1
# Norm: 13.17, NNZs: 100, Bias: -5.911545, T: 98700, Avg. loss: 0.011729
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.16, NNZs: 100, Bias: -5.902137, T: 197400, Avg. loss: 0.010885
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 13.08, NNZs: 100, Bias: -6.090515, T: 296100, Avg. loss: 0.010782
# Total training time: 0.11 seconds.
# -- Epoch 5
# Norm: 13.55, NNZs: 100, Bias: -7.169163, T: 493500, Avg. loss: 0.014789
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.48, NNZs: 100, Bias: -7.409204, T: 592200, Avg. loss: 0.014719
# Total training time: 0.23 seconds.
# -- Epoch 7
# Norm: 13.53, NNZs: 100, Bias: -7.237377, T: 690900, Avg. loss: 0.014761
# Total training time: 0.27 seconds.
# Convergence after 7 epochs took 0.27 seconds
# -- Epoch 1
# Norm: 13.40, NNZs: 100, Bias: -7.305012, T: 98700, Avg. loss: 0.013634
# Total training time: 0.05 seconds.
# -- Epoch 2
# Norm: 13.34, NNZs: 100, Bias: -7.281104, T: 197400, Avg. loss: 0.012525
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 13.34, NNZs: 100, Bias: -7.174471, T: 296100, Avg. loss: 0.012465
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 13.36, NNZs: 100, Bias: -7.196174, T: 394800, Avg. loss: 0.012593
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 13.38, NNZs: 100, Bias: -7.138446, T: 493500, Avg. loss: 0.012544
# Total training time: 0.21 seconds.
# -- Epoch 6
# Norm: 13.38, NNZs: 100, Bias: -7.143453, T: 592200, Avg. loss: 0.012516
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 13.37, NNZs: 100, Bias: -7.171660, T: 690900, Avg. loss: 0.012495
# Total training time: 0.29 seconds.
# Convergence after 7 epochs took 0.29 seconds
# -- Epoch 1
# Norm: 12.49, NNZs: 100, Bias: -6.232998, T: 98700, Avg. loss: 0.018834
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.52, NNZs: 100, Bias: -6.362661, T: 197400, Avg. loss: 0.017725
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.49, NNZs: 100, Bias: -6.520540, T: 296100, Avg. loss: 0.017612
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.57, NNZs: 100, Bias: -6.219690, T: 394800, Avg. loss: 0.017664
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 12.55, NNZs: 100, Bias: -6.327809, T: 493500, Avg. loss: 0.017569
# Total training time: 0.19 seconds.
# -- Epoch 6
# Norm: 12.54, NNZs: 100, Bias: -6.334870, T: 592200, Avg. loss: 0.017538
# Total training time: 0.23 seconds.
# -- Epoch 7
# Norm: 12.54, NNZs: 100, Bias: -6.339998, T: 690900, Avg. loss: 0.017578
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 13.34, NNZs: 100, Bias: -6.163082, T: 98700, Avg. loss: 0.012038
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.38, NNZs: 100, Bias: -6.121819, T: 197400, Avg. loss: 0.011225
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 13.33, NNZs: 100, Bias: -6.222635, T: 296100, Avg. loss: 0.011122
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 13.33, NNZs: 100, Bias: -6.181541, T: 394800, Avg. loss: 0.011119
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 13.33, NNZs: 100, Bias: -6.194056, T: 493500, Avg. loss: 0.011123
# Total training time: 0.19 seconds.
# -- Epoch 6
# Norm: 13.31, NNZs: 100, Bias: -6.237266, T: 592200, Avg. loss: 0.011060
# Total training time: 0.23 seconds.
# Convergence after 6 epochs took 0.23 seconds
# -- Epoch 1
# Norm: 12.80, NNZs: 100, Bias: -4.797051, T: 98700, Avg. loss: 0.019610
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.67, NNZs: 100, Bias: -5.116687, T: 197400, Avg. loss: 0.018361
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 12.70, NNZs: 100, Bias: -4.906434, T: 296100, Avg. loss: 0.018340
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 12.69, NNZs: 100, Bias: -4.887123, T: 394800, Avg. loss: 0.018293
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 12.69, NNZs: 100, Bias: -4.872165, T: 493500, Avg. loss: 0.018305
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.67, NNZs: 100, Bias: -5.003720, T: 592200, Avg. loss: 0.018217
# Total training time: 0.25 seconds.
# -- Epoch 7
# Norm: 12.68, NNZs: 100, Bias: -4.929481, T: 690900, Avg. loss: 0.018275
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 12.69, NNZs: 100, Bias: -5.997655, T: 98700, Avg. loss: 0.017105
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.60, NNZs: 100, Bias: -6.073757, T: 197400, Avg. loss: 0.015667
# Total training time: 0.07 seconds.
# -- Epoch 3
# Norm: 12.61, NNZs: 100, Bias: -6.176077, T: 296100, Avg. loss: 0.015810
# Total training time: 0.11 seconds.
# -- Epoch 4
# Norm: 12.65, NNZs: 100, Bias: -6.131892, T: 394800, Avg. loss: 0.015820
# Total training time: 0.15 seconds.
# -- Epoch 5
# Norm: 12.66, NNZs: 100, Bias: -6.110216, T: 493500, Avg. loss: 0.015745
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.70, NNZs: 100, Bias: -5.975862, T: 592200, Avg. loss: 0.015815
# Total training time: 0.23 seconds.
# -- Epoch 7
# Norm: 12.69, NNZs: 100, Bias: -5.995728, T: 690900, Avg. loss: 0.015733
# Total training time: 0.27 seconds.
# Convergence after 7 epochs took 0.27 seconds
# -- Epoch 1
# Norm: 13.73, NNZs: 100, Bias: -5.714488, T: 98700, Avg. loss: 0.015894
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.60, NNZs: 100, Bias: -5.865857, T: 197400, Avg. loss: 0.014484
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.61, NNZs: 100, Bias: -5.882414, T: 296100, Avg. loss: 0.014605
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.62, NNZs: 100, Bias: -5.841899, T: 394800, Avg. loss: 0.014592
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.62, NNZs: 100, Bias: -5.845131, T: 493500, Avg. loss: 0.014571
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.62, NNZs: 100, Bias: -5.863485, T: 592200, Avg. loss: 0.014565
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 13.62, NNZs: 100, Bias: -5.867793, T: 690900, Avg. loss: 0.014551
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 12.92, NNZs: 100, Bias: -5.739884, T: 98700, Avg. loss: 0.012978
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.82, NNZs: 100, Bias: -5.601655, T: 197400, Avg. loss: 0.012125
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.78, NNZs: 100, Bias: -5.678808, T: 296100, Avg. loss: 0.012133
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 12.76, NNZs: 100, Bias: -5.723155, T: 394800, Avg. loss: 0.012090
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 12.78, NNZs: 100, Bias: -5.615460, T: 493500, Avg. loss: 0.012139
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.77, NNZs: 100, Bias: -5.610305, T: 592200, Avg. loss: 0.012116
# Total training time: 0.24 seconds.
# Convergence after 6 epochs took 0.24 seconds
# -- Epoch 1
# Norm: 13.29, NNZs: 100, Bias: -4.868099, T: 98700, Avg. loss: 0.018282
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.19, NNZs: 100, Bias: -5.052732, T: 197400, Avg. loss: 0.017050
# Total training time: 0.09 seconds.
# -- Epoch 3
# Norm: 13.19, NNZs: 100, Bias: -5.058107, T: 296100, Avg. loss: 0.017054
# Total training time: 0.13 seconds.
# -- Epoch 4
# Norm: 13.21, NNZs: 100, Bias: -4.912603, T: 394800, Avg. loss: 0.017081
# Total training time: 0.17 seconds.
# -- Epoch 5
# Norm: 13.20, NNZs: 100, Bias: -5.089124, T: 493500, Avg. loss: 0.017032
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.20, NNZs: 100, Bias: -5.034238, T: 592200, Avg. loss: 0.017007
# Total training time: 0.25 seconds.
# -- Epoch 7
# Norm: 13.20, NNZs: 100, Bias: -5.014368, T: 690900, Avg. loss: 0.017021
# Total training time: 0.29 seconds.
# Convergence after 7 epochs took 0.29 seconds
# -- Epoch 1
# Norm: 12.89, NNZs: 100, Bias: -5.811426, T: 98700, Avg. loss: 0.020079
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.86, NNZs: 100, Bias: -5.704117, T: 197400, Avg. loss: 0.018564
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.84, NNZs: 100, Bias: -5.731107, T: 296100, Avg. loss: 0.018515
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.85, NNZs: 100, Bias: -5.687197, T: 394800, Avg. loss: 0.018562
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.83, NNZs: 100, Bias: -5.770687, T: 493500, Avg. loss: 0.018490
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.83, NNZs: 100, Bias: -5.828266, T: 592200, Avg. loss: 0.018496
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 12.83, NNZs: 100, Bias: -5.777892, T: 690900, Avg. loss: 0.018476
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 12.06, NNZs: 100, Bias: -6.406020, T: 98700, Avg. loss: 0.023231
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.08, NNZs: 100, Bias: -6.571574, T: 197400, Avg. loss: 0.021918
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.13, NNZs: 100, Bias: -6.484539, T: 296100, Avg. loss: 0.021934
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.11, NNZs: 100, Bias: -6.617430, T: 394800, Avg. loss: 0.021782
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.15, NNZs: 100, Bias: -6.476088, T: 493500, Avg. loss: 0.021840
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.18, NNZs: 100, Bias: -6.353949, T: 592200, Avg. loss: 0.021805
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 12.16, NNZs: 100, Bias: -6.448351, T: 690900, Avg. loss: 0.021718
# Total training time: 0.28 seconds.
# Convergence after 7 epochs took 0.28 seconds
# -- Epoch 1
# Norm: 13.24, NNZs: 100, Bias: -7.630224, T: 98700, Avg. loss: 0.016100
# Total training time: 0.05 seconds.
# -- Epoch 2
# Norm: 13.41, NNZs: 100, Bias: -7.494977, T: 197400, Avg. loss: 0.015241
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.42, NNZs: 100, Bias: -7.527666, T: 296100, Avg. loss: 0.015123
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.45, NNZs: 100, Bias: -7.416017, T: 394800, Avg. loss: 0.015054
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.43, NNZs: 100, Bias: -7.522423, T: 493500, Avg. loss: 0.015067
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 13.42, NNZs: 100, Bias: -7.552601, T: 592200, Avg. loss: 0.015042
# Total training time: 0.25 seconds.
# Convergence after 6 epochs took 0.25 seconds
# -- Epoch 1
# Norm: 12.38, NNZs: 100, Bias: -7.011521, T: 98700, Avg. loss: 0.023057
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 12.45, NNZs: 100, Bias: -6.966113, T: 197400, Avg. loss: 0.021323
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 12.47, NNZs: 100, Bias: -6.816777, T: 296100, Avg. loss: 0.021192
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 12.44, NNZs: 100, Bias: -6.955690, T: 394800, Avg. loss: 0.021137
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 12.47, NNZs: 100, Bias: -6.872748, T: 493500, Avg. loss: 0.021192
# Total training time: 0.20 seconds.
# -- Epoch 6
# Norm: 12.46, NNZs: 100, Bias: -6.897828, T: 592200, Avg. loss: 0.021137
# Total training time: 0.24 seconds.
# -- Epoch 7
# Norm: 12.47, NNZs: 100, Bias: -6.873951, T: 690900, Avg. loss: 0.021151
# Total training time: 0.27 seconds.
# Convergence after 7 epochs took 0.27 seconds
# -- Epoch 1
# Norm: 13.13, NNZs: 100, Bias: -5.230608, T: 98700, Avg. loss: 0.019674
# Total training time: 0.04 seconds.
# -- Epoch 2
# Norm: 13.12, NNZs: 100, Bias: -5.295002, T: 197400, Avg. loss: 0.018206
# Total training time: 0.08 seconds.
# -- Epoch 3
# Norm: 13.08, NNZs: 100, Bias: -5.502979, T: 296100, Avg. loss: 0.018032
# Total training time: 0.12 seconds.
# -- Epoch 4
# Norm: 13.11, NNZs: 100, Bias: -5.308793, T: 394800, Avg. loss: 0.018133
# Total training time: 0.16 seconds.
# -- Epoch 5
# Norm: 13.10, NNZs: 100, Bias: -5.445296, T: 493500, Avg. loss: 0.018069
# Total training time: 0.19 seconds.
# -- Epoch 6
# Norm: 13.11, NNZs: 100, Bias: -5.413637, T: 592200, Avg. loss: 0.018091
# Total training time: 0.23 seconds.
# -- Epoch 7
# Norm: 13.10, NNZs: 100, Bias: -5.473007, T: 690900, Avg. loss: 0.018072
# Total training time: 0.27 seconds.
# Convergence after 7 epochs took 0.27 seconds
# Training time:  44.088510036468506
# [Parallel(n_jobs=1)]: Done 141 out of 141 | elapsed:   43.5s finished
# ['/home/huy/face_recog/models/sgd/RBFSampler_losslog_04072020_181307.sgd']

# %% [markdown]
# ### Train MLPerception

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ### Evaluate the model

# %% [markdown]
# #### Eclid Distance

# %%
import multiprocessing
from functools import partial
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

# %matplotlib inline
import logging
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
logging.getLogger('matplotlib.font_manager').disabled = True
logging.getLogger('matplotlib.colorbar').disabled = True

# %%
def run_evaluation(samples, test_set_type, threshold=0.0, method=[True, True, True], **kwargs):
    ### Euclid ###
    if method[0]:
        plt.clf()
        recog = FaceRecognition(
            feature_extractor_type='dlib',
            classifier_method='euclid',
            model_dir='/home/huy/face_recog/models/simple_distance/'
        )

        classes = [s.replace('\n', '') for s in recog.classes]
        classes.append('unknown')

        actual = []
        predict = []

        def process(samples):
            actual = []
            predict = []
            with tqdm(total=len(samples)) as pbar:
                for feature, label in samples:
                    predict_id = recog.recog([feature], threshold=1-threshold)
                    predict_id = predict_id[0][0].split('\n')[0]
                    actual.append(label)
                    predict.append(predict_id)
                    pbar.update(1)
            return (actual, predict)

        # samples_batch = split_into(samples, 6)

        # with multiprocessing.Pool(6) as pool:
        #     return_value = pool.map(process, samples_batch)
        #     r1, r2 = list(zip(*return_value))
        #     actual.extend(r1)
        #     predict.extend(r2)
        actual, predict = process(samples)

        cfm = confusion_matrix(actual, predict)
        norm_cfm = confusion_matrix(actual, predict, labels=classes, normalize='true')
        acc = accuracy_score(actual, predict)
        recall = recall_score(actual, predict, average='weighted')
        pre = precision_score(actual, predict, average='weighted')

        for i in range(len(norm_cfm)):
            for k in range(len(norm_cfm)):
                norm_cfm[i][k] = round(norm_cfm[i][k], 2)

        print('result:', acc, recall, pre)

        df_cm = pd.DataFrame(norm_cfm, classes, classes)
        # plt.figure(figsize=(10,7))
        sn.set(font_scale=0.1) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 1}) # font size

        # plt.show()
        plt.savefig(f'{test_set_type}/cfm_euclid.eps', format='eps', dpi=1200)

        ### Ignore unknown
        plt.clf()
        classes = [s.replace('\n', '') for s in recog.classes]

        actual_without_unknown = []
        predict_without_unknown = []

        unknown_count = 0
        for i in range(len(actual)):
            if predict[i] != 'unknown':
                actual_without_unknown.append(actual[i])
                predict_without_unknown.append(predict[i])
            else:
                unknown_count += 1

        cfm = confusion_matrix(actual_without_unknown, predict_without_unknown)
        norm_cfm = confusion_matrix(actual, predict, labels=classes, normalize='true')
        acc = accuracy_score(actual_without_unknown, predict_without_unknown)
        recall = recall_score(actual_without_unknown, predict_without_unknown, average='weighted')
        pre = precision_score(actual_without_unknown, predict_without_unknown, average='weighted')
        unknown_rate = unknown_count / len(predict)

        for i in range(len(norm_cfm)):
            for k in range(len(norm_cfm)):
                norm_cfm[i][k] = round(norm_cfm[i][k], 2)

        print('result_without_unknown:', acc, recall, pre)
        print('unknown_rate:', unknown_rate)

        df_cm = pd.DataFrame(norm_cfm, classes, classes)
        sn.set(font_scale=0.1) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 1}) # font size

        # plt.show()
        plt.savefig(f'{test_set_type}/cfm_euclid_without_unknown.eps', format='eps', dpi=1200)

    ### End Euclid ###

    ### SVM ###
    if method[1]:
        plt.clf()
        recog = FaceRecognition(
            feature_extractor_type='dlib',
            classifier_method='svm',
            model_path = kwargs['SVM_MODEL']
        )

        classes = [s.replace('\n', '') for s in recog.svm_clf.classes_]
        classes.append('unknown')

        actual = []
        predict = []

        def process(samples):
            actual = []
            predict = []
            with tqdm(total=len(samples)) as pbar:
                for feature, label in samples:
                    predict_id = recog.recog([feature], threshold=threshold)
                    predict_id = predict_id[0].split('\n')[0]
                    actual.append(label)
                    predict.append(predict_id)
                    pbar.update(1)
            return (actual, predict)

        # samples_batch = split_into(samples, 6)

        # with multiprocessing.Pool(6) as pool:
        #     return_value = pool.map(process, samples_batch)
        #     r1, r2 = list(zip(*return_value))
        #     actual.extend(r1)
        #     predict.extend(r2)
        actual, predict = process(samples)

        cfm = confusion_matrix(actual, predict)
        norm_cfm = confusion_matrix(actual, predict, labels=classes, normalize='true')
        acc = accuracy_score(actual, predict)
        recall = recall_score(actual, predict, average='weighted')
        pre = precision_score(actual, predict, average='weighted')

        for i in range(len(norm_cfm)):
            for k in range(len(norm_cfm)):
                norm_cfm[i][k] = round(norm_cfm[i][k], 2)

        print('result:', acc, recall, pre)

        df_cm = pd.DataFrame(norm_cfm, classes, classes)
        sn.set(font_scale=0.1) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 1}) # font size

        # plt.show()
        plt.savefig(f'{test_set_type}/cfm_svm.eps', format='eps', dpi=1200)


        ### Ignore unknown
        plt.clf()
        classes = [s.replace('\n', '') for s in recog.svm_clf.classes_]

        actual_without_unknown = []
        predict_without_unknown = []

        unknown_count = 0
        for i in range(len(actual)):
            if predict[i] != 'unknown':
                actual_without_unknown.append(actual[i])
                predict_without_unknown.append(predict[i])
            else:
                unknown_count += 1

        cfm = confusion_matrix(actual_without_unknown, predict_without_unknown)
        norm_cfm = confusion_matrix(actual, predict, labels=classes, normalize='true')
        acc = accuracy_score(actual_without_unknown, predict_without_unknown)
        recall = recall_score(actual_without_unknown, predict_without_unknown, average='weighted')
        pre = precision_score(actual_without_unknown, predict_without_unknown, average='weighted')
        unknown_rate = unknown_count / len(predict)

        for i in range(len(norm_cfm)):
            for k in range(len(norm_cfm)):
                norm_cfm[i][k] = round(norm_cfm[i][k], 2)

        print('result_without_unknown:', acc, recall, pre)
        print('unknown_rate:', unknown_rate)

        df_cm = pd.DataFrame(norm_cfm, classes, classes)
        sn.set(font_scale=0.1) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 1}) # font size

        # plt.show()
        plt.savefig(f'{test_set_type}/cfm_svm_without_unknown.eps', format='eps', dpi=1200)


    #### KNN #####
    if method[2]:
        plt.clf()
        recog = FaceRecognition(
            feature_extractor_type='dlib',
            classifier_method='knn',
            model_dir='/home/huy/face_recog/models/knn'
        )

        classes = recog.knn.classes_
        classes = [s.replace('\n', '') for s in classes]
        actual = []
        predict = []

        def process(samples):
            actual = []
            predict = []
            with tqdm(total=len(samples)) as pbar:
                for feature, label in samples:
                    predict_id = recog.recog([feature], threshold=threshold)
                    predict_id = predict_id[0].split('\n')[0]
                    actual.append(label)
                    predict.append(predict_id)
                    pbar.update(1)
            return (actual, predict)

        # samples_batch = split_into(samples, 6)

        # with multiprocessing.Pool(6) as pool:
        #     return_value = pool.map(process, samples_batch)
        #     r1, r2 = list(zip(*return_value))
        #     actual.extend(r1)
        #     predict.extend(r2)
        actual, predict = process(samples)

        cfm = confusion_matrix(actual, predict)
        norm_cfm = confusion_matrix(actual, predict, labels=classes, normalize='true')
        acc = accuracy_score(actual, predict)
        recall = recall_score(actual, predict, average='weighted')
        pre = precision_score(actual, predict, average='weighted')

        for i in range(len(norm_cfm)):
            for k in range(len(norm_cfm)):
                norm_cfm[i][k] = round(norm_cfm[i][k], 2)

        print('result:', acc, recall, pre)

        df_cm = pd.DataFrame(norm_cfm, classes, classes)
        # plt.figure(figsize=(10,7))
        sn.set(font_scale=0.1) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 1}) # font size

        # plt.show()
        plt.savefig(f'{test_set_type}/cfm_knn.eps', format='eps', dpi=1200)

        ### Ignore unknown
        plt.clf()
        classes = [s.replace('\n', '') for s in recog.knn.classes_]

        actual_without_unknown = []
        predict_without_unknown = []

        unknown_count = 0
        for i in range(len(actual)):
            if predict[i] != 'unknown':
                actual_without_unknown.append(actual[i])
                predict_without_unknown.append(predict[i])
            else:
                unknown_count += 1

        cfm = confusion_matrix(actual_without_unknown, predict_without_unknown)
        norm_cfm = confusion_matrix(actual, predict, labels=classes, normalize='true')
        acc = accuracy_score(actual_without_unknown, predict_without_unknown)
        recall = recall_score(actual_without_unknown, predict_without_unknown, average='weighted')
        pre = precision_score(actual_without_unknown, predict_without_unknown, average='weighted')
        unknown_rate = unknown_count / len(predict)

        for i in range(len(norm_cfm)):
            for k in range(len(norm_cfm)):
                norm_cfm[i][k] = round(norm_cfm[i][k], 2)

        print('result_without_unknown:', acc, recall, pre)
        print('unknown_rate:', unknown_rate)

        df_cm = pd.DataFrame(norm_cfm, classes, classes)
        sn.set(font_scale=0.1) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 1}) # font size

        # plt.show()
        plt.savefig(f'{test_set_type}/cfm_knn_without_unknown.eps', format='eps', dpi=1200)

    ### End KNN ###

# %%
test_type = ['wm', 'hm']
samples_list = []
# SVM_MODEL = svm_trained_model_path
SVM_MODEL = '/home/huy/face_recog/models/sgd/RBFSampler_losslog_04072020_181307.sgd'
rbf_feature = RBFSampler(gamma=1, random_state=1)
for t in test_type:
    samples = joblib.load(f'/home/huy/face_recog/encoded_data/aug5_test_{t}/features.joblib')
    gaussian_features = rbf_feature.fit_transform(samples)
    run_evaluation(gaussian_features, t, threshold=0.0, method=[False, True, False], SVM_MODEL=SVM_MODEL)
#     run_evaluation(samples, t, threshold=0.0, method=[False, True, False], SVM_MODEL=SVM_MODEL)
# Out:
#   0%|          | 0/24000 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/home/huy/capstone/godofeye/lib/blueeyes/face_recognition/recognition.py", line 245, in _svm_recog
#     probas_list = self.svm_clf.predict_proba(features)
#   File "/home/huy/venv/cv/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py", line 1002, in _predict_proba
#     return self._predict_proba_lr(X)
#   File "/home/huy/venv/cv/lib/python3.8/site-packages/sklearn/linear_model/_base.py", line 307, in _predict_proba_lr
#     prob = self.decision_function(X)
#   File "/home/huy/venv/cv/lib/python3.8/site-packages/sklearn/linear_model/_base.py", line 272, in decision_function
#     raise ValueError("X has %d features per sample; expecting %d"
# ValueError: X has 128 features per sample; expecting 100
#   0%|          | 0/24000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-eff3108555fa> in <module>
#       5 for t in test_type:
#       6     samples = joblib.load(f'/home/huy/face_recog/encoded_data/aug5_test_{t}/features.joblib')
# ----> 7     run_evaluation(samples, t, threshold=0.0, method=[False, True, False], SVM_MODEL=SVM_MODEL)
#
# <ipython-input-12-7658e78d1505> in run_evaluation(samples, test_set_type, threshold, method, **kwargs)
#     128         #     actual.extend(r1)
#     129         #     predict.extend(r2)
# --> 130         actual, predict = process(samples)
#     131
#     132         cfm = confusion_matrix(actual, predict)
#
# <ipython-input-12-7658e78d1505> in process(samples)
#     115                 for feature, label in samples:
#     116                     predict_id = recog.recog([feature], threshold=threshold)
# --> 117                     predict_id = predict_id[0].split('\n')[0]
#     118                     actual.append(label)
#     119                     predict.append(predict_id)
#
# IndexError: list index out of range

# %%
def split_into(lst, n_part):
    parts = []
    part_size = len(lst)//n_part
    i = 0
    while i < n_part:
        parts.append(lst[i*part_size:(i*part_size+part_size)])
        i += 1
    for i in range(len(lst) % n_part):
        key, value = lst[n_part*part_size+i]
        parts[i][key] = value
    return parts

# %%
recog = FaceRecognition(
    classifier_method='euclid',
    model_dir='/home/huy/face_recog/models/simple_distance/'
)
TP_count = 0
UNK_count = 0
num_samples = 0
for id, img_paths in test_set_dict.items():
    for path in img_paths:
        img = cv2.imread(path, 1)
        predict_id = recog.recog(img,[[0,0,img.shape[1],img.shape[0]]], threshold=0.9)
        predict_id = predict_id[0][0].split('\n')[0]
        if predict_id == id:
            TP_count += 1
        elif predict_id == 'unknown':
            UNK_count +=1
        num_samples += 1
# TP rate don't care UNK
print('num_samples\t', 'TP_count\t', 'UNK_count\t')
print(num_samples, TP_count, UNK_count)
print('TP Rate ',TP_count/(num_samples-UNK_count))
# False rate
# print(1 - (TP_count+UNK_count)/num_samples
print('UNK rate ', UNK_count/num_samples)

# %%
recog = FaceRecognition(
    model_dir='/home/huy/face_recog/models/knn/', 
   classifier_method='knn'
)
TP_count = 0
UNK_count = 0
num_samples = 0
for id, img_paths in test_set_dict.items():
    for path in img_paths:
        img = cv2.imread(path, 1)
        predict_id = recog.recog(img,[[0,0,img.shape[1],img.shape[0]]], threshold=0.5)
        predict_id = predict_id[0][0].split('\n')[0]
        if predict_id == id:
            TP_count += 1
        elif predict_id == 'unknown':
            UNK_count +=1
        num_samples += 1
# TP rate don't care UNK
print('num_samples\t', 'TP_count\t', 'UNK_count\t')
print(num_samples, TP_count, UNK_count)
print('TP Rate ',TP_count/(num_samples-UNK_count))
# False rate
# print(1 - (TP_count+UNK_count)/num_samples
print('UNK rate ', UNK_count/num_samples)

# %%
recog = FaceRecognition(
    model_dir='/home/huy/models/simple_distance/',
    feature_extractor_type='face_recognition'
)
TP_count = 0
UNK_count = 0
num_samples = 0
for id, img_paths in test_set_dict.items():
    for path in img_paths:
        img = cv2.imread(path, 1)
        predict_id = recog.recog(img,[[0,0,img.shape[1],img.shape[0]]], threshold=0.5)
        predict_id = predict_id[0][0].split('\n')[0]
        if predict_id == id:
            TP_count += 1
        elif predict_id == 'unknown':
            UNK_count +=1
        num_samples += 1
# TP rate don't care UNK
print('num_samples\t', 'TP_count\t', 'UNK_count\t')
print(num_samples, TP_count, UNK_count)
print('TP Rate ',TP_count/(num_samples-UNK_count))
# False rate
# print(1 - (TP_count+UNK_count)/num_samples
print('UNK rate ', UNK_count/num_samples)
